# %%
## Mount the google drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !nvidia-smi
# Out:
# Fri Jun  2 03:05:01 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P8    11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
cd '/content'
# Out:
# /content

# %%
# !gdown --folder 11G7U03Im4FrWGIUytzweoMQQRjAY6rHM
# Out:
# Retrieving folder list
# Retrieving folder 128AAV0APny_9ZcoVOBRFQHm06dhGNvw5 ASR
# Processing file 12AqjM0PWd7k2jZmZnbHafwT4qGGhx7uk SampleSubmission_Advanced.csv
# Processing file 12OF_w_WYXx209DCVTFY33aWRrXunGg2K Test_Advanced.csv
# Processing file 12IH0HWtIyBs1GH8r4ubPghPqWUYEXP1- Test_Advanced.zip
# Processing file 12Ewpa7eRrqkss_eIIwgSBD1mOmbNk-F4 Train.csv
# Processing file 12KKGl3TW2x0APXh-x_ZCa93ZYrG9Y03X Train.zip
# Processing file 12CNcLuKTvWHnRipqylwnS_cWKYkbnXj6 VariableDefinitions.csv
# Retrieving folder 11JFd890ixDaGnKvxjlcmoKun0n1wudfl CV
# Processing file 129MzZveaBWGK3A2no6Nk0v__--7Gc4vl SampleSubmission.csv
# Processing file 11Ql0LhoCHcxsZD2wa9iCoIumZ4_rQWgU suspects.zip
# Processing file 11WSCpM5buI6KEhkTSRZhXm73Duzw_z1r test.csv
# Processing file 11m8Cp653NUhTzFkZ11NqKZzogslnWDox Test.zip
# Processing file 11_qCG2a-Px-jXQU4Zn4hhkRZz2pOjbsY train_labels.zip
# Processing file 11sirhbOu0P-e8hiNiLUe6hoxanVNnlVG Train.zip
# Processing file 11fH1SwxUWqmFvMJfAJgFMV1Arv2638Fw val_labels.zip
# Processing file 11ZDR1-fpTOx_rrW1j3gmGps48fCPn-Ik Validation.zip
# Retrieving folder list completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From: https://drive.google.com/uc?id=12AqjM0PWd7k2jZmZnbHafwT4qGGhx7uk
# To: /content/Advanced/ASR/SampleSubmission_Advanced.csv
# 100% 204k/204k [00:00<00:00, 177MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=12OF_w_WYXx209DCVTFY33aWRrXunGg2K
# To: /content/Advanced/ASR/Test_Advanced.csv
# 100% 264k/264k [00:00<00:00, 173MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=12IH0HWtIyBs1GH8r4ubPghPqWUYEXP1-
# To: /content/Advanced/ASR/Test_Advanced.zip
# 100% 1.10G/1.10G [00:10<00:00, 108MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=12Ewpa7eRrqkss_eIIwgSBD1mOmbNk-F4
# To: /content/Advanced/ASR/Train.csv
# 100% 280k/280k [00:00<00:00, 195MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=12KKGl3TW2x0APXh-x_ZCa93ZYrG9Y03X
# To: /content/Advanced/ASR/Train.zip
# 100% 361M/361M [00:06<00:00, 55.5MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=12CNcLuKTvWHnRipqylwnS_cWKYkbnXj6
# To: /content/Advanced/ASR/VariableDefinitions.csv
# 100% 131/131 [00:00<00:00, 928kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=129MzZveaBWGK3A2no6Nk0v__--7Gc4vl
# To: /content/Advanced/CV/SampleSubmission.csv
# 100% 27.3k/27.3k [00:00<00:00, 86.9MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=11Ql0LhoCHcxsZD2wa9iCoIumZ4_rQWgU
# To: /content/Advanced/CV/suspects.zip
# 100% 42.4M/42.4M [00:00<00:00, 160MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=11WSCpM5buI6KEhkTSRZhXm73Duzw_z1r
# To: /content/Advanced/CV/test.csv
# 100% 17.6k/17.6k [00:00<00:00, 63.0MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=11m8Cp653NUhTzFkZ11NqKZzogslnWDox
# To: /content/Advanced/CV/Test.zip
# 100% 1.17G/1.17G [00:14<00:00, 81.7MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=11_qCG2a-Px-jXQU4Zn4hhkRZz2pOjbsY
# To: /content/Advanced/CV/train_labels.zip
# 100% 1.59M/1.59M [00:00<00:00, 209MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=11sirhbOu0P-e8hiNiLUe6hoxanVNnlVG
# To: /content/Advanced/CV/Train.zip
# 100% 4.07G/4.07G [00:32<00:00, 126MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=11fH1SwxUWqmFvMJfAJgFMV1Arv2638Fw
# To: /content/Advanced/CV/val_labels.zip
# 100% 218k/218k [00:00<00:00, 172MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=11ZDR1-fpTOx_rrW1j3gmGps48fCPn-Ik
# To: /content/Advanced/CV/Validation.zip
# 100% 562M/562M [00:04<00:00, 116MB/s]
# Download completed

# %%
# !unzip "/content/Advanced/CV/Train.zip" -d "train_images"

# !unzip "/content/Advanced/CV/train_labels.zip" -d "train_labels"

# !unzip "/content/Advanced/CV/Validation.zip" -d "val_images"

# !unzip "/content/Advanced/CV/val_labels.zip" -d "val_labels"

# !unzip "/content/Advanced/CV/Test.zip" -d "test_images"

# !unzip "/content/Advanced/CV/suspects.zip" -d "suspects"
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: train_labels/image_0460.txt
#  extracting: train_labels/image_0479.txt
#  extracting: train_labels/image_0465.txt
#  extracting: train_labels/image_0475.txt
#  extracting: train_labels/image_0477.txt
#  extracting: train_labels/image_0474.txt
#  extracting: train_labels/image_0457.txt
#  extracting: train_labels/image_0473.txt
#  extracting: train_labels/image_0472.txt
#  extracting: train_labels/image_0466.txt
#  extracting: train_labels/image_0481.txt
#  extracting: train_labels/image_0471.txt
#  extracting: train_labels/image_0469.txt
#  extracting: train_labels/image_0484.txt
#  extracting: train_labels/image_0482.txt
#  extracting: train_labels/image_0459.txt
#  extracting: train_labels/image_0476.txt
#  extracting: train_labels/image_0468.txt
#  extracting: train_labels/image_0489.txt
#  extracting: train_labels/image_0505.txt
#  extracting: train_labels/image_0494.txt
#  extracting: train_labels/image_0495.txt
#  extracting: train_labels/image_0491.txt
#  extracting: train_labels/image_0508.txt
#  extracting: train_labels/image_0500.txt
#  extracting: train_labels/image_0511.txt
#  extracting: train_labels/image_0499.txt
#  extracting: train_labels/image_0487.txt
#  extracting: train_labels/image_0498.txt
#  extracting: train_labels/image_0502.txt
#  extracting: train_labels/image_0509.txt
#  extracting: train_labels/image_0492.txt
#  extracting: train_labels/image_0504.txt
#  extracting: train_labels/image_0497.txt
#  extracting: train_labels/image_0507.txt
#  extracting: train_labels/image_0506.txt
#  extracting: train_labels/image_0490.txt
#  extracting: train_labels/image_0513.txt
#  extracting: train_labels/image_0486.txt
#  extracting: train_labels/image_0493.txt
#  extracting: train_labels/image_0503.txt
#  extracting: train_labels/image_0512.txt
#  extracting: train_labels/image_0501.txt
#  extracting: train_labels/image_0488.txt
#  extracting: train_labels/image_0496.txt
#  extracting: train_labels/image_0510.txt
#  extracting: train_labels/image_0543.txt
#  extracting: train_labels/image_0534.txt
#  extracting: train_labels/image_0528.txt
#  extracting: train_labels/image_0537.txt
#  extracting: train_labels/image_0529.txt
#  extracting: train_labels/image_0526.txt
#  extracting: train_labels/image_0527.txt
#  extracting: train_labels/image_0539.txt
#  extracting: train_labels/image_0519.txt
#  extracting: train_labels/image_0521.txt
#  extracting: train_labels/image_0532.txt
#  extracting: train_labels/image_0515.txt
#  extracting: train_labels/image_0538.txt
#  extracting: train_labels/image_0540.txt
#  extracting: train_labels/image_0520.txt
#  extracting: train_labels/image_0530.txt
#  extracting: train_labels/image_0535.txt
#  extracting: train_labels/image_0525.txt
#  extracting: train_labels/image_0517.txt
#  extracting: train_labels/image_0542.txt
#  extracting: train_labels/image_0516.txt
#  extracting: train_labels/image_0544.txt
#  extracting: train_labels/image_0514.txt
#  extracting: train_labels/image_0541.txt
#  extracting: train_labels/image_0536.txt
#  extracting: train_labels/image_0524.txt
#  extracting: train_labels/image_0531.txt
#  extracting: train_labels/image_0533.txt
#  extracting: train_labels/image_0518.txt
#  extracting: train_labels/image_0522.txt
#  extracting: train_labels/image_0523.txt
#  extracting: train_labels/image_0546.txt
#  extracting: train_labels/image_0563.txt
#  extracting: train_labels/image_0550.txt
#  extracting: train_labels/image_0570.txt
#  extracting: train_labels/image_0558.txt
#  extracting: train_labels/image_0571.txt
#  extracting: train_labels/image_0549.txt
#  extracting: train_labels/image_0562.txt
#  extracting: train_labels/image_0547.txt
#  extracting: train_labels/image_0560.txt
#  extracting: train_labels/image_0555.txt
#  extracting: train_labels/image_0548.txt
#  extracting: train_labels/image_0556.txt
#  extracting: train_labels/image_0566.txt
#  extracting: train_labels/image_0557.txt
#  extracting: train_labels/image_0565.txt
#  extracting: train_labels/image_0561.txt
#  extracting: train_labels/image_0552.txt
#  extracting: train_labels/image_0551.txt
#  extracting: train_labels/image_0569.txt
#  extracting: train_labels/image_0568.txt
#  extracting: train_labels/image_0559.txt
#  extracting: train_labels/image_0553.txt
#  extracting: train_labels/image_0545.txt
#  extracting: train_labels/image_0567.txt
#  extracting: train_labels/image_0554.txt
#  extracting: train_labels/image_0564.txt
#  extracting: train_labels/image_0580.txt
#  extracting: train_labels/image_0572.txt
#  extracting: train_labels/image_0585.txt
#  extracting: train_labels/image_0576.txt
#  extracting: train_labels/image_0592.txt
#  extracting: train_labels/image_0589.txt
#  extracting: train_labels/image_0587.txt
#  extracting: train_labels/image_0598.txt
#  extracting: train_labels/image_0586.txt
#  extracting: train_labels/image_0578.txt
#  extracting: train_labels/image_0582.txt
#  extracting: train_labels/image_0594.txt
#  extracting: train_labels/image_0579.txt
#  extracting: train_labels/image_0593.txt
#  extracting: train_labels/image_0591.txt
#  extracting: train_labels/image_0577.txt
#  extracting: train_labels/image_0573.txt
#  extracting: train_labels/image_0597.txt
#  extracting: train_labels/image_0590.txt
#  extracting: train_labels/image_0596.txt
#  extracting: train_labels/image_0583.txt
#  extracting: train_labels/image_0581.txt
#  extracting: train_labels/image_0574.txt
#  extracting: train_labels/image_0575.txt
#  extracting: train_labels/image_0588.txt
#  extracting: train_labels/image_0595.txt
#  extracting: train_labels/image_0584.txt
#  extracting: train_labels/image_0608.txt
#  extracting: train_labels/image_0603.txt
#  extracting: train_labels/image_0626.txt
#  extracting: train_labels/image_0604.txt
#  extracting: train_labels/image_0613.txt
#  extracting: train_labels/image_0628.txt
#  extracting: train_labels/image_0627.txt
#  extracting: train_labels/image_0606.txt
#  extracting: train_labels/image_0615.txt
#  extracting: train_labels/image_0605.txt
#  extracting: train_labels/image_0623.txt
#  extracting: train_labels/image_0619.txt
#  extracting: train_labels/image_0616.txt
#  extracting: train_labels/image_0614.txt
#  extracting: train_labels/image_0601.txt
#  extracting: train_labels/image_0609.txt
#  extracting: train_labels/image_0624.txt
#  extracting: train_labels/image_0599.txt
#  extracting: train_labels/image_0620.txt
#  extracting: train_labels/image_0611.txt
#  extracting: train_labels/image_0607.txt
#  extracting: train_labels/image_0610.txt
#  extracting: train_labels/image_0622.txt
#  extracting: train_labels/image_0600.txt
#  extracting: train_labels/image_0621.txt
#  extracting: train_labels/image_0612.txt
#  extracting: train_labels/image_0602.txt
#  extracting: train_labels/image_0625.txt
#  extracting: train_labels/image_0618.txt
#  extracting: train_labels/image_0617.txt
#  extracting: train_labels/image_0629.txt
#  extracting: train_labels/image_0632.txt
#  extracting: train_labels/image_0653.txt
#  extracting: train_labels/image_0645.txt
#  extracting: train_labels/image_0634.txt
#  extracting: train_labels/image_0633.txt
#  extracting: train_labels/image_0654.txt
#  extracting: train_labels/image_0630.txt
#  extracting: train_labels/image_0638.txt
#  extracting: train_labels/image_0643.txt
#  extracting: train_labels/image_0640.txt
#  extracting: train_labels/image_0648.txt
#  extracting: train_labels/image_0642.txt
#  extracting: train_labels/image_0641.txt
#  extracting: train_labels/image_0649.txt
#  extracting: train_labels/image_0639.txt
#  extracting: train_labels/image_0635.txt
#  extracting: train_labels/image_0651.txt
#  extracting: train_labels/image_0646.txt
#  extracting: train_labels/image_0644.txt
#  extracting: train_labels/image_0637.txt
#  extracting: train_labels/image_0636.txt
#  extracting: train_labels/image_0631.txt
#  extracting: train_labels/image_0650.txt
#  extracting: train_labels/image_0652.txt
#  extracting: train_labels/image_0647.txt
#  extracting: train_labels/image_0655.txt
#  extracting: train_labels/image_0659.txt
#  extracting: train_labels/image_0682.txt
#  extracting: train_labels/image_0670.txt
#  extracting: train_labels/image_0679.txt
#  extracting: train_labels/image_0663.txt
#  extracting: train_labels/image_0664.txt
#  extracting: train_labels/image_0680.txt
#  extracting: train_labels/image_0660.txt
# Archive:  /content/Advanced/CV/Validation.zip
#  extracting: val_images/image_0637.png
#  extracting: val_images/image_0632.png
#  extracting: val_images/image_0705.png
#  extracting: val_images/image_0700.png
#  extracting: val_images/image_0638.png
#  extracting: val_images/image_0660.png
#  extracting: val_images/image_0661.png
#  extracting: val_images/image_0693.png
#  extracting: val_labels/image_0018.txt
#  extracting: val_labels/image_0013.txt
#  extracting: val_labels/image_0001.txt
#  extracting: val_labels/image_0003.txt
#  extracting: val_labels/image_0007.txt
#  extracting: val_labels/image_0019.txt
#  extracting: val_labels/image_0006.txt
#  extracting: val_labels/image_0014.txt
#  extracting: val_labels/image_0004.txt
#  extracting: val_labels/image_0017.txt
#  extracting: val_labels/image_0005.txt
#  extracting: val_labels/image_0002.txt
#  extracting: val_labels/image_0036.txt
#  extracting: val_labels/image_0025.txt
#  extracting: val_labels/image_0062.txt
#  extracting: val_labels/image_0072.txt
#  extracting: val_labels/image_0047.txt
#  extracting: val_labels/image_0065.txt
#  extracting: val_labels/image_0033.txt
#  extracting: val_labels/image_0064.txt
#  extracting: val_labels/image_0060.txt
#  extracting: val_labels/image_0051.txt
#  extracting: val_labels/image_0092.txt
#  extracting: val_labels/image_0074.txt
#  extracting: val_labels/image_0037.txt
#  extracting: val_labels/image_0054.txt
#  extracting: val_labels/image_0091.txt
#  extracting: val_labels/image_0040.txt
#  extracting: val_labels/image_0057.txt
#  extracting: val_labels/image_0087.txt
#  extracting: val_labels/image_0090.txt
#  extracting: val_labels/image_0061.txt
#  extracting: val_labels/image_0071.txt
#  extracting: val_labels/image_0030.txt
#  extracting: val_labels/image_0088.txt
#  extracting: val_labels/image_0027.txt
#  extracting: val_labels/image_0046.txt
#  extracting: val_labels/image_0089.txt
#  extracting: val_labels/image_0086.txt
#  extracting: val_labels/image_0038.txt
#  extracting: val_labels/image_0032.txt
#  extracting: val_labels/image_0093.txt
#  extracting: val_labels/image_0083.txt
#  extracting: val_labels/image_0084.txt
#  extracting: val_labels/image_0080.txt
#  extracting: val_labels/image_0039.txt
#  extracting: val_labels/image_0022.txt
#  extracting: val_labels/image_0055.txt
#  extracting: val_labels/image_0058.txt
#  extracting: val_labels/image_0048.txt
#  extracting: val_labels/image_0075.txt
#  extracting: val_labels/image_0073.txt
#  extracting: val_labels/image_0079.txt
#  extracting: val_labels/image_0045.txt
#  extracting: val_labels/image_0050.txt
#  extracting: val_labels/image_0021.txt
#  extracting: val_labels/image_0035.txt
#  extracting: val_labels/image_0052.txt
#  extracting: val_labels/image_0076.txt
#  extracting: val_labels/image_0078.txt
#  extracting: val_labels/image_0082.txt
#  extracting: val_labels/image_0081.txt
#  extracting: val_labels/image_0068.txt
#  extracting: val_labels/image_0034.txt
#  extracting: val_labels/image_0069.txt
#  extracting: val_labels/image_0067.txt
#  extracting: val_labels/image_0023.txt
#  extracting: val_labels/image_0042.txt
#  extracting: val_labels/image_0044.txt
#  extracting: val_labels/image_0085.txt
#  extracting: val_labels/image_0063.txt
#  extracting: val_labels/image_0024.txt
#  extracting: val_labels/image_0070.txt
#  extracting: val_labels/image_0059.txt
#  extracting: val_labels/image_0066.txt
#  extracting: val_labels/image_0029.txt
#  extracting: val_labels/image_0041.txt
#  extracting: val_labels/image_0056.txt
#  extracting: val_labels/image_0026.txt
#  extracting: val_labels/image_0094.txt
#  extracting: val_labels/image_0028.txt
#  extracting: val_labels/image_0043.txt
#  extracting: val_labels/image_0031.txt
#  extracting: val_labels/image_0049.txt
#  extracting: val_labels/image_0053.txt
#  extracting: val_labels/image_0077.txt
#  extracting: val_labels/image_0170.txt
#  extracting: val_labels/image_0161.txt
#  extracting: val_labels/image_0155.txt
#  extracting: val_labels/image_0107.txt
#  extracting: val_labels/image_0099.txt
#  extracting: val_labels/image_0123.txt
#  extracting: val_labels/image_0154.txt
#  extracting: val_labels/image_0153.txt
#  extracting: val_labels/image_0149.txt
#  extracting: val_labels/image_0138.txt
#  extracting: val_labels/image_0136.txt
#  extracting: val_labels/image_0129.txt
#  extracting: val_labels/image_0117.txt
#  extracting: val_labels/image_0103.txt
#  extracting: val_labels/image_0164.txt
#  extracting: val_labels/image_0169.txt
#  extracting: val_labels/image_0143.txt
#  extracting: val_labels/image_0112.txt
#  extracting: val_labels/image_0160.txt
#  extracting: val_labels/image_0166.txt
#  extracting: val_labels/image_0114.txt
#  extracting: val_labels/image_0120.txt
#  extracting: val_labels/image_0165.txt
#  extracting: val_labels/image_0157.txt
#  extracting: val_labels/image_0124.txt
#  extracting: val_labels/image_0097.txt
#  extracting: val_labels/image_0104.txt
#  extracting: val_labels/image_0133.txt
#  extracting: val_labels/image_0105.txt
#  extracting: val_labels/image_0139.txt
#  extracting: val_labels/image_0159.txt
#  extracting: val_labels/image_0162.txt
#  extracting: val_labels/image_0131.txt
#  extracting: val_labels/image_0115.txt
#  extracting: val_labels/image_0125.txt
#  extracting: val_labels/image_0119.txt
#  extracting: val_labels/image_0151.txt
#  extracting: val_labels/image_0158.txt
#  extracting: val_labels/image_0095.txt
#  extracting: val_labels/image_0108.txt
#  extracting: val_labels/image_0135.txt
#  extracting: val_labels/image_0116.txt
#  extracting: val_labels/image_0141.txt
#  extracting: val_labels/image_0132.txt
#  extracting: val_labels/image_0101.txt
#  extracting: val_labels/image_0100.txt
#  extracting: val_labels/image_0127.txt
#  extracting: val_labels/image_0118.txt
#  extracting: val_labels/image_0121.txt
#  extracting: val_labels/image_0142.txt
#  extracting: val_labels/image_0134.txt
#  extracting: val_labels/image_0144.txt
#  extracting: val_labels/image_0145.txt
#  extracting: val_labels/image_0167.txt
#  extracting: val_labels/image_0113.txt
#  extracting: val_labels/image_0098.txt
#  extracting: val_labels/image_0137.txt
#  extracting: val_labels/image_0126.txt
#  extracting: val_labels/image_0152.txt
#  extracting: val_labels/image_0140.txt
#  extracting: val_labels/image_0148.txt
#  extracting: val_labels/image_0122.txt
#  extracting: val_labels/image_0111.txt
#  extracting: val_labels/image_0163.txt
#  extracting: val_labels/image_0147.txt
#  extracting: val_labels/image_0109.txt
# ...
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0480.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0479.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0427.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0459.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0460.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0466.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0433.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0569.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0535.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0532.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0575.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0501.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0523.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0562.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0555.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0519.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0541.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0556.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0534.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0580.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0515.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0533.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0529.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0514.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0563.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0571.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0554.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0510.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0509.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0516.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0573.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0543.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0508.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0559.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0530.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0528.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0538.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0561.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0504.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0577.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0576.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0578.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0542.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0565.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0521.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0560.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0570.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0568.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0537.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0525.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0567.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0566.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0502.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0526.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0548.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0503.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0564.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0522.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0552.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0507.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0505.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0550.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0506.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0545.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0512.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0513.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0579.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0547.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0511.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0524.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0500.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0553.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0499.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0558.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0518.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0539.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0520.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0540.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0517.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0546.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0549.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0527.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0551.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0531.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0536.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0574.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0544.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0557.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0572.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0620.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0647.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0619.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0600.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0657.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0607.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0659.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0630.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0641.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0650.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0654.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0612.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0603.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0637.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0586.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0628.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0598.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0652.png
#  extracting: suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0629.png

# %%
# !unzip "/content/gdrive/MyDrive/Train.zip" -d "train_images"

# !unzip "/content/gdrive/MyDrive/train_labels.zip" -d "train_labels"

# !unzip "/content/gdrive/MyDrive/Validation.zip" -d "val_images"

# !unzip "/content/gdrive/MyDrive/val_labels.zip" -d "val_labels"

# !unzip "/content/gdrive/MyDrive/Test.zip" -d "test_images"

# !unzip "/content/gdrive/MyDrive/suspects.zip" -d "suspects"

# %%
train_images_path = '/content/train_images'
train_labels_path = '/content/train_labels'
val_images_path = '/content/val_images'
val_labels_path = '/content/val_labels'

# %%
import cv2
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
import os

train_crops_path = "train_crops"
num_plushies = 200
os.mkdir(train_crops_path)

for i in range(num_plushies):
    os.mkdir(os.path.join(train_crops_path, str(i)))

# %%
val_crops_path = "val_crops"
num_plushies = 10
os.mkdir(val_crops_path)

for i in range(num_plushies):
    os.mkdir(os.path.join(val_crops_path, str(i)))

# %%
import cv2
import numpy as np
import pandas as pd
import os

images_path = train_images_path
labels_path = train_labels_path
annotated_images_path = train_crops_path


for label_name in os.listdir(labels_path):
    if label_name[-4:] != ".txt":
        continue
    image_name = label_name[:-4] + ".png"
    # print("Checking", image_name)

    image_path = os.path.join(images_path, image_name)
    label_path = os.path.join(labels_path, label_name)

    df = pd.read_csv(label_path, delim_whitespace=True, header=None)
    df.columns = ["cat", "xc", "yc", "w", "h"]

    img = cv2.imread(image_path)
    img_h, img_w = img.shape[:2]

    for i in range(df.shape[0]):
        bb = df.iloc[i]
        cat = str(int(bb["cat"]))
        tl = (int((bb["xc"] - bb["w"]/2) * img_w), int((bb["yc"] - bb["h"]/2) * img_h))
        br = (int((bb["xc"] + bb["w"]/2) * img_w), int((bb["yc"] + bb["h"]/2) * img_h))

        cropped_img = img[tl[1]:br[1], tl[0]:br[0]]
        annotated_img_name = f"{cat}_{len(os.listdir(os.path.join(annotated_images_path, cat)))}.png"
        cv2.imwrite(os.path.join(annotated_images_path, cat, annotated_img_name), cropped_img)

# %%
import cv2
import numpy as np
import pandas as pd
import os

images_path = val_images_path
labels_path = val_labels_path
annotated_images_path = val_crops_path


for label_name in os.listdir(labels_path):
    if label_name[-4:] != ".txt":
        continue
    image_name = label_name[:-4] + ".png"
#     print("Checking", image_name)

    image_path = os.path.join(images_path, image_name)
    label_path = os.path.join(labels_path, label_name)

    df = pd.read_csv(label_path, delim_whitespace=True, header=None)
    df.columns = ["cat", "xc", "yc", "w", "h"]

    img = cv2.imread(image_path)
    img_h, img_w = img.shape[:2]

    for i in range(df.shape[0]):
        bb = df.iloc[i]
        cat = str(int(bb["cat"]))
        tl = (int((bb["xc"] - bb["w"]/2) * img_w), int((bb["yc"] - bb["h"]/2) * img_h))
        br = (int((bb["xc"] + bb["w"]/2) * img_w), int((bb["yc"] + bb["h"]/2) * img_h))

        cropped_img = img[tl[1]:br[1], tl[0]:br[0]]
        annotated_img_name = f"{cat}_{len(os.listdir(os.path.join(annotated_images_path, cat)))}.png"
        cv2.imwrite(os.path.join(annotated_images_path, cat, annotated_img_name), cropped_img)

# %%
image = cv2.imread(f'{train_crops_path}/0/0_21.png')
plt.imshow(image)

# %%
import os
import random

counts = {}

crops_path = train_crops_path
num_plushies = 200

for i in range(num_plushies):
    counts[i] = len(os.listdir(os.path.join(crops_path, str(i))))
print(counts)

lines = []

def add_match(plushie, num1, num2):
    line = f"{plushie} {num1} {num2}\n"
    lines.append(line)

def add_mismatch(plushie1, num1, plushie2, num2):
    line = f"{plushie1} {num1} {plushie2} {num2}\n"
    lines.append(line)

len_data = 4000

for i in range(len_data):
    # print(i)
    plushie = random.choice(list(counts.keys()))

    num1, num2 = random.randrange(counts[plushie]), random.randrange(counts[plushie])

    while not (os.path.exists(f"{crops_path}/{plushie}/{plushie}_{num1}.png") and os.path.exists(f"{crops_path}/{plushie}/{plushie}_{num2}.png")):
        print(num1, num2, plushie)
        num1, num2 = random.randrange(counts[plushie]), random.randrange(counts[plushie])
    
    add_match(plushie, num1, num2)

for i in range(len_data):
    # print(i)
    plushie1, plushie2 = random.choice(list(counts.keys())), random.choice(list(counts.keys()))
    while plushie1 == plushie2:
        plushie1, plushie2 = random.choice(list(counts.keys())), random.choice(list(counts.keys()))

    num1, num2 = random.randrange(counts[plushie1]), random.randrange(counts[plushie2])
                              
                              
    while not (os.path.exists(f"{crops_path}/{plushie1}/{plushie1}_{num1}.png") and os.path.exists(f"{crops_path}/{plushie2}/{plushie2}_{num2}.png")):
        num1, num2 = random.randrange(counts[plushie1]), random.randrange(counts[plushie2])

    add_mismatch(plushie1, num1, plushie2, num2)


f = open("plushie_pairs_train.txt", "a")
f.writelines(lines)
f.close()
# Out:
# {0: 67, 1: 65, 2: 66, 3: 65, 4: 65, 5: 65, 6: 61, 7: 66, 8: 66, 9: 64, 10: 66, 11: 65, 12: 65, 13: 64, 14: 66, 15: 65, 16: 66, 17: 65, 18: 66, 19: 65, 20: 65, 21: 66, 22: 65, 23: 66, 24: 65, 25: 65, 26: 65, 27: 65, 28: 64, 29: 65, 30: 65, 31: 65, 32: 65, 33: 66, 34: 66, 35: 65, 36: 65, 37: 65, 38: 65, 39: 65, 40: 65, 41: 64, 42: 65, 43: 65, 44: 66, 45: 65, 46: 66, 47: 63, 48: 66, 49: 65, 50: 65, 51: 65, 52: 64, 53: 66, 54: 65, 55: 66, 56: 66, 57: 65, 58: 65, 59: 65, 60: 65, 61: 63, 62: 65, 63: 64, 64: 65, 65: 65, 66: 66, 67: 66, 68: 65, 69: 65, 70: 66, 71: 66, 72: 66, 73: 65, 74: 63, 75: 64, 76: 65, 77: 65, 78: 65, 79: 63, 80: 63, 81: 64, 82: 64, 83: 63, 84: 64, 85: 64, 86: 64, 87: 56, 88: 56, 89: 56, 90: 58, 91: 62, 92: 62, 93: 58, 94: 65, 95: 63, 96: 57, 97: 61, 98: 61, 99: 56, 100: 60, 101: 56, 102: 61, 103: 60, 104: 57, 105: 61, 106: 60, 107: 54, 108: 57, 109: 59, 110: 60, 111: 56, 112: 57, 113: 60, 114: 55, 115: 56, 116: 56, 117: 61, 118: 57, 119: 57, 120: 57, 121: 56, 122: 56, 123: 55, 124: 59, 125: 59, 126: 59, 127: 56, 128: 60, 129: 67, 130: 58, 131: 62, 132: 59, 133: 58, 134: 56, 135: 58, 136: 59, 137: 64, 138: 58, 139: 57, 140: 56, 141: 59, 142: 57, 143: 62, 144: 60, 145: 60, 146: 60, 147: 61, 148: 63, 149: 61, 150: 60, 151: 59, 152: 59, 153: 60, 154: 61, 155: 59, 156: 56, 157: 57, 158: 61, 159: 59, 160: 60, 161: 59, 162: 63, 163: 59, 164: 54, 165: 59, 166: 62, 167: 57, 168: 58, 169: 59, 170: 59, 171: 61, 172: 60, 173: 56, 174: 58, 175: 61, 176: 61, 177: 60, 178: 62, 179: 59, 180: 60, 181: 58, 182: 58, 183: 58, 184: 59, 185: 59, 186: 60, 187: 59, 188: 59, 189: 59, 190: 61, 191: 61, 192: 59, 193: 59, 194: 61, 195: 57, 196: 63, 197: 62, 198: 59, 199: 58}

# %%
import os
import random

counts = {}

crops_path = val_crops_path
num_plushies = 10

for i in range(num_plushies):
    counts[i] = len(os.listdir(os.path.join(crops_path, str(i))))
print(counts)

lines = []

def add_match(plushie, num1, num2):
    line = f"{plushie} {num1} {num2}\n"
    lines.append(line)

def add_mismatch(plushie1, num1, plushie2, num2):
    line = f"{plushie1} {num1} {plushie2} {num2}\n"
    lines.append(line)

len_data = 400

for i in range(len_data):
    # print(i)
    plushie = random.choice(list(counts.keys()))

    num1, num2 = random.randrange(counts[plushie]), random.randrange(counts[plushie])

    while not (os.path.exists(f"{crops_path}/{plushie}/{plushie}_{num1}.png") and os.path.exists(f"{crops_path}/{plushie}/{plushie}_{num2}.png")):
        print(num1, num2, plushie)
        num1, num2 = random.randrange(counts[plushie]), random.randrange(counts[plushie])
    
    add_match(plushie, num1, num2)

for i in range(len_data):
    # print(i)
    plushie1, plushie2 = random.choice(list(counts.keys())), random.choice(list(counts.keys()))
    while plushie1 == plushie2:
        plushie1, plushie2 = random.choice(list(counts.keys())), random.choice(list(counts.keys()))

    num1, num2 = random.randrange(counts[plushie1]), random.randrange(counts[plushie2])
                              
                              
    while not (os.path.exists(f"{crops_path}/{plushie1}/{plushie1}_{num1}.png") and os.path.exists(f"{crops_path}/{plushie2}/{plushie2}_{num2}.png")):
        num1, num2 = random.randrange(counts[plushie1]), random.randrange(counts[plushie2])

    add_mismatch(plushie1, num1, plushie2, num2)


f = open("plushie_pairs_val.txt", "a")
f.writelines(lines)
f.close()
# Out:
# {0: 179, 1: 177, 2: 169, 3: 163, 4: 163, 5: 163, 6: 166, 7: 169, 8: 173, 9: 177}

# %%
import torch
import matplotlib.pyplot as plt

def get_default_device():
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')
    
    
def to_device(data, device):
    if isinstance(data, (list, tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

def show_img(img1, img2):
    axs = plt.figure(figsize=(9, 9)).subplots(1, 2)
    axs[0].imshow(img1)
    axs[1].imshow(img2)


def accuracy(preds, labels):
    preds = torch.flatten(preds)
    preds[preds > 0] = 1
    preds[preds < 0] = 0
    return torch.sum(preds == labels).item() / len(labels)


class DeviceDataLoader():
    def __init__(self, dl, device):
        self.dl = dl
        self.device = device
    
    def __iter__(self):
        for batch in self.dl:
            yield to_device(batch, self.device)
    
    def __len__(self):
        return len(self.dl)

# %%
import torchvision.transforms as tt
import cv2

class BGR2RGB:
    def __call__(self, image):
        return cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

class SquarePad:
    def __call__(self, image):
        max_wh = max(image.shape[:2])
        p_left, p_top = [(max_wh - s) // 2 for s in image.shape[:2]]
        p_right, p_bottom = [max_wh - (s+pad) for s, pad in zip(image.shape[:2], [p_left, p_top])]
        return cv2.copyMakeBorder(image, p_top, p_bottom, p_left, p_right, cv2.BORDER_CONSTANT, None, value = 0)


class Resize():
    def __init__(self, output_size=(128, 128)):
        assert isinstance(output_size, (tuple))
        self.output_size = output_size

    def __call__(self, image):
        return cv2.resize(image, self.output_size, interpolation = cv2.INTER_LINEAR)

class Transforms:
    def __init__(self):
        self.transform = tt.Compose([BGR2RGB(), 
                        SquarePad(),
                        Resize((128, 128)),
                        tt.ToTensor(),
                        tt.Normalize(0, 0.5)])

    def __call__(self, image):
        return self.transform(image)

# %%
from torchvision.models import resnet50, ResNet50_Weights
from torch import cat
import torch.nn as nn

class SiameseNetwork(nn.Module):
    """
        https://github.com/pytorch/examples/tree/main/siamese_network

        BCE Loss
    """
    def __init__(self):
        super(SiameseNetwork, self).__init__()
        self.resnet = resnet50(ResNet50_Weights.DEFAULT)

        for ct, child in enumerate(self.resnet.children()):
            if ct < 6:
                for param in child.parameters():
                    param.requires_grad = False


        self.fc_in_features = self.resnet.fc.in_features
        
        # remove the last layer of resnet18 (linear layer which is before avgpool layer)
        self.resnet = nn.Sequential(*(list(self.resnet.children())[:-1]))

        # add linear layers to compare between the features of the two images
        self.fc = nn.Sequential(
            nn.Linear(self.fc_in_features * 2, 256),
            nn.ReLU(inplace=True),
            nn.Linear(256, 1),
        )


    def get_embeddings(self, x):
        output = self.resnet(x)
        output = output.view(output.size()[0], -1)
        return output

    def forward(self, input1, input2):
        output1 = self.get_embeddings(input1)
        output2 = self.get_embeddings(input2)
        output = cat((output1, output2), 1)
        output = self.fc(output)
        
        return output

# %%
import os
import matplotlib.pyplot as plt

from PIL import Image
import cv2

from torch.utils.data import Dataset

class PlushieTrainDataset(Dataset):
    
    def __init__(self, filepath, img_dir, transform=None):
        self.samples = []
        self.img_dir = img_dir
        self.transform = transform

        with open(filepath, 'r') as f:
            self.samples = [line.strip() for line in f]

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, i):
        line = self.samples[i].split()
        if len(line) == 3:
            anchor_name, anchor_num, img_num = line
            img_name = anchor_name
            is_same = 1
        elif len(line) == 4:
            anchor_name, anchor_num, img_name, img_num = line
            is_same = 0
        else:
            print(len(line), line)
            raise Exception("Shouldn't be here")
        
        anchor = cv2.imread(os.path.join(self.img_dir, str(anchor_name), f"{anchor_name}_{anchor_num}.png"))
        img = cv2.imread(os.path.join(self.img_dir, img_name, f"{img_name}_{img_num}.png"))
        
        if self.transform:
            anchor = self.transform(anchor)
            img = self.transform(img)

        return anchor, img, is_same

# %%
import numpy as np
import torch

def loss_batch(model, loss_func, anchor, image, label, opt=None, metric=None): # Update model weights and return metrics given xb, yb, model
    preds = model(anchor, image)
    loss = loss_func(preds, label.unsqueeze(1).float())
    
    if opt is not None:
        loss.backward()
        opt.step()
        opt.zero_grad()
        
    metric_result = None
    if metric is not None:
        metric_result = metric(preds, label)
        
    return loss.item(), len(anchor), metric_result

def fit(epochs, model, loss_func, train_dl, val_dl, opt_func=torch.optim.SGD, lr=0.01, metric=None):
    train_losses, val_losses, val_metrics = [] , [], []
    
    opt = opt_func(model.parameters(), lr=lr)
    
    for epoch in range(1, epochs+1):
        model.train() # Setting for pytorch - training mode
        for anchor,image,label in train_dl:
            train_loss, _, _ = loss_batch(model, loss_func, anchor, image, label, opt) # update weights
            
        model.eval() # Setting - eval mode
        val_loss, total, val_metric = evaluate(model, loss_func, val_dl, metric)
        
        train_losses.append(train_loss)
        val_losses.append(val_loss)
        val_metrics.append(val_metric)
        
        if metric is None:
            print("Epoch [{}], train_loss: {:.4f}, val_loss: {:.4f}".format(
            epoch, train_loss, val_loss))
        else:
            print("Epoch [{}], train_loss: {:.4f}, val_loss: {:.4f}, val_{}: {:.4f}".format(
            epoch, train_loss, val_loss, metric.__name__, val_metric))
            
    return train_losses, val_losses, val_metrics

def evaluate(model, loss_func, val_dl, metric=None):
    with torch.no_grad():
        results = [loss_batch(model, loss_func, anchor, image, label, metric=metric) for anchor, image, label in val_dl]
        
        losses, nums, metrics = zip(*results)
        total = np.sum(nums)
        
        avg_loss = np.sum(np.multiply(losses, nums)) / total
        
        avg_metric = None
        if metric is not None:
            avg_metric = np.sum(np.multiply(metrics, nums)) / total
            
        return avg_loss, total, avg_metric

train_filepath = "plushie_pairs_train.txt"
train_img_dir = train_crops_path
val_filepath = "plushie_pairs_val.txt"
val_img_dir = val_crops_path
train_bs = 16
test_bs = 8
num_epochs = 30
lr = 0.0001

torch.autograd.set_detect_anomaly(True)

transform = Transforms()
train_dataset = PlushieTrainDataset(filepath=train_filepath, img_dir=train_img_dir, transform=transform)
valid_dataset = PlushieTrainDataset(filepath=val_filepath, img_dir=val_img_dir, transform=transform)
network = SiameseNetwork()

print("The length of Train set is {}".format(len(train_dataset)))
print("The length of Valid set is {}".format(len(valid_dataset)))

train_dl = torch.utils.data.DataLoader(train_dataset, batch_size=train_bs, shuffle=True, num_workers=4)
val_dl = torch.utils.data.DataLoader(valid_dataset, batch_size=test_bs, shuffle=True, num_workers=4)

device = get_default_device()
train_dl = DeviceDataLoader(train_dl, device)
val_dl = DeviceDataLoader(val_dl, device)
to_device(network, device)

criterion = torch.nn.BCEWithLogitsLoss()
optimizer = torch.optim.Adam

train_losses, val_losses, val_metrics = fit(num_epochs, network, criterion, 
                                        train_dl, val_dl, optimizer, lr, accuracy)

torch.save(network.state_dict(), 'model.pth')
# Out:
# The length of Train set is 8000
# The length of Valid set is 800
# Epoch [1], train_loss: 0.6434, val_loss: 0.5917, val_accuracy: 0.6937
# Epoch [2], train_loss: 0.4350, val_loss: 0.5432, val_accuracy: 0.7300
# Epoch [3], train_loss: 0.4563, val_loss: 0.5071, val_accuracy: 0.7450
# Epoch [4], train_loss: 0.4371, val_loss: 0.4684, val_accuracy: 0.7887
# Epoch [5], train_loss: 0.3405, val_loss: 0.4780, val_accuracy: 0.7887
# Epoch [6], train_loss: 0.2570, val_loss: 0.6296, val_accuracy: 0.7837
# Epoch [7], train_loss: 0.0997, val_loss: 0.6029, val_accuracy: 0.7662
# Epoch [8], train_loss: 0.0870, val_loss: 0.4976, val_accuracy: 0.8050
# Epoch [9], train_loss: 0.3721, val_loss: 0.7514, val_accuracy: 0.7700
# Epoch [10], train_loss: 0.0128, val_loss: 0.7384, val_accuracy: 0.7750
# Epoch [11], train_loss: 0.1929, val_loss: 0.7299, val_accuracy: 0.7688
# Epoch [12], train_loss: 0.4303, val_loss: 0.5652, val_accuracy: 0.8125
# Epoch [13], train_loss: 0.0044, val_loss: 0.7555, val_accuracy: 0.8037
# Epoch [14], train_loss: 0.0475, val_loss: 0.8459, val_accuracy: 0.7825
# Epoch [15], train_loss: 0.1352, val_loss: 0.8736, val_accuracy: 0.7863
# Epoch [16], train_loss: 0.0057, val_loss: 0.7234, val_accuracy: 0.8050
# Epoch [17], train_loss: 0.0023, val_loss: 0.8629, val_accuracy: 0.7800
# Epoch [18], train_loss: 0.0086, val_loss: 1.1679, val_accuracy: 0.7925
# Epoch [19], train_loss: 0.0186, val_loss: 0.9914, val_accuracy: 0.7887
# Epoch [20], train_loss: 0.1765, val_loss: 0.7700, val_accuracy: 0.7638
# Epoch [21], train_loss: 0.0082, val_loss: 0.8235, val_accuracy: 0.7725
# Epoch [22], train_loss: 0.0027, val_loss: 0.8338, val_accuracy: 0.7863
# Epoch [23], train_loss: 0.0251, val_loss: 0.9429, val_accuracy: 0.7913
# Epoch [24], train_loss: 0.0392, val_loss: 0.8422, val_accuracy: 0.7850
# Epoch [25], train_loss: 0.0108, val_loss: 0.7764, val_accuracy: 0.8013
# Epoch [26], train_loss: 0.0644, val_loss: 1.0003, val_accuracy: 0.7725
# Epoch [27], train_loss: 0.0032, val_loss: 1.4959, val_accuracy: 0.7512
# Epoch [28], train_loss: 0.0235, val_loss: 0.9768, val_accuracy: 0.8037
# Epoch [29], train_loss: 0.0352, val_loss: 0.9701, val_accuracy: 0.8000
# Epoch [30], train_loss: 0.0236, val_loss: 1.1476, val_accuracy: 0.7788

# %%
def predict_image(model, target, img, transform=None, device=torch.device('cpu')):
    xb, xb2 = transform(target).unsqueeze(0), transform(img).unsqueeze(0) # Convert to batch of 1
    model.eval()
    yb = model(xb.to(device), xb2.to(device))
    return yb

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15935, done.
# remote: Counting objects: 100% (104/104), done.
# remote: Compressing objects: 100% (46/46), done.
# remote: Total 15935 (delta 65), reused 87 (delta 58), pack-reused 15831
# Receiving objects: 100% (15935/15935), 14.53 MiB | 15.48 MiB/s, done.
# Resolving deltas: 100% (10939/10939), done.

# %%
# !pip install -r yolov5/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting gitpython>=3.1.30 (from -r yolov5/requirements.txt (line 5))
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 12.8 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.3 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 6)) (3.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 7)) (1.22.4)
# Requirement already satisfied: opencv-python>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 8)) (4.7.0.72)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 9)) (8.4.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 10)) (5.9.5)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 11)) (6.0)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 12)) (2.27.1)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 13)) (1.10.1)
# Collecting thop>=0.1.1 (from -r yolov5/requirements.txt (line 14))
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: torch>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 15)) (2.0.1+cu118)
# Requirement already satisfied: torchvision>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 16)) (0.15.2+cu118)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 17)) (4.65.0)
# Collecting ultralytics>=8.0.111 (from -r yolov5/requirements.txt (line 18))
#   Downloading ultralytics-8.0.112-py3-none-any.whl (593 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 593.1/593.1 kB 58.3 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 27)) (1.5.3)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 28)) (0.12.2)
# Requirement already satisfied: setuptools>=65.5.1 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 42)) (67.7.2)
# Collecting gitdb<5,>=4.0.1 (from gitpython>=3.1.30->-r yolov5/requirements.txt (line 5))
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 10.1 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->-r yolov5/requirements.txt (line 12)) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->-r yolov5/requirements.txt (line 12)) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->-r yolov5/requirements.txt (line 12)) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->-r yolov5/requirements.txt (line 12)) (3.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->-r yolov5/requirements.txt (line 15)) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->-r yolov5/requirements.txt (line 15)) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->-r yolov5/requirements.txt (line 15)) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->-r yolov5/requirements.txt (line 15)) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->-r yolov5/requirements.txt (line 15)) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.0->-r yolov5/requirements.txt (line 15)) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.7.0->-r yolov5/requirements.txt (line 15)) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.7.0->-r yolov5/requirements.txt (line 15)) (16.0.5)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->-r yolov5/requirements.txt (line 27)) (2022.7.1)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython>=3.1.30->-r yolov5/requirements.txt (line 5))
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.7.0->-r yolov5/requirements.txt (line 15)) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.7.0->-r yolov5/requirements.txt (line 15)) (1.3.0)
# Installing collected packages: smmap, gitdb, gitpython, ultralytics, thop
# Successfully installed gitdb-4.0.10 gitpython-3.1.31 smmap-5.0.0 thop-0.1.1.post2209072238 ultralytics-8.0.112

# %%
import pandas as pd

bb_ann = {"Image_ID": [], "class": [], "confidence": [], "ymin": [], "xmin": [], 
          "ymax": [], "xmax": []}

yolo_repo_path = 'yolov5'
yolo_model_path = '/content/best.pt'
reid_model_path = "/content/model.pth"

yolo_model = torch.hub.load(yolo_repo_path, 'custom', path=yolo_model_path, source='local')

reid_model = SiameseNetwork()
reid_model.load_state_dict(torch.load(reid_model_path, map_location=torch.device('cuda')))

test_dir = "test_images"
suspect_dir = "suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops"

reid_transforms = Transforms()

def detect_objects(image_name):
    image_path = os.path.join(test_dir, image_name)
    print("Image Path: ", image_path)
    suspect_path = os.path.join(suspect_dir, image_name)
    print("Suspect Path: ", suspect_path)

    img = cv2.imread(image_path)
    suspect = cv2.imread(suspect_path)
    
    img_h, img_w = img.shape[:2]

    print("Image Height: ", img_h)
    print("Image Width: ", img_w )

    # Perform object detection
    results = yolo_model(img)

    # Print the detected objects with their classes, confidence scores, and bounding box coordinates
    for result in results.xyxy[0].tolist():
        class_id = int(result[5])
        confidence = result[4]
        x1, y1, x2, y2 = result[:4]
        plushie = img[int(y1):int(y2), int(x1):int(x2)]
        match_confidence = float(predict_image(reid_model, suspect, plushie, transform=reid_transforms))
        plushie_class = 1 if match_confidence > 0 else 0

        bb_ann["Image_ID"].append(image_name[:-4])
        bb_ann["class"].append(plushie_class) 
        bb_ann["confidence"].append(confidence)
        bb_ann["ymin"].append(y1 / img_h)
        bb_ann["xmin"].append(x1 / img_w)
        bb_ann["ymax"].append(y2 / img_h)
        bb_ann["xmax"].append(x2 / img_w)
        
    if not results.xyxy[0].tolist():
        bb_ann["Image_ID"].append(image_name[:-4])
        bb_ann["class"].append(0) 
        bb_ann["confidence"].append(0)
        bb_ann["ymin"].append(0)
        bb_ann["xmin"].append(0)
        bb_ann["ymax"].append(0)
        bb_ann["xmax"].append(0)

for i, image_name in enumerate(os.listdir(test_dir)):
    print(image_name)
    detect_objects(image_name)

df = pd.DataFrame.from_dict(bb_ann)
df.to_csv("results.csv", index=False)
# Out:
# YOLOv5 🚀 v7.0-175-g5f11555 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...
# Streaming output truncated to the last 5000 lines.
# image_0761.png
# Image Path:  test_images/image_0761.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0761.png
# Image Height:  720
# Image Width:  1280
# image_0641.png
# Image Path:  test_images/image_0641.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0641.png
# Image Height:  720
# Image Width:  1280
# image_1174.png
# Image Path:  test_images/image_1174.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1174.png
# Image Height:  720
# Image Width:  1280
# image_1140.png
# Image Path:  test_images/image_1140.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1140.png
# Image Height:  720
# Image Width:  1280
# image_1481.png
# Image Path:  test_images/image_1481.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1481.png
# Image Height:  720
# Image Width:  1280
# image_0337.png
# Image Path:  test_images/image_0337.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0337.png
# Image Height:  720
# Image Width:  1280
# image_1294.png
# Image Path:  test_images/image_1294.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1294.png
# Image Height:  720
# Image Width:  1280
# image_1326.png
# Image Path:  test_images/image_1326.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1326.png
# Image Height:  720
# Image Width:  1280
# image_0704.png
# Image Path:  test_images/image_0704.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0704.png
# Image Height:  720
# Image Width:  1280
# image_0552.png
# Image Path:  test_images/image_0552.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0552.png
# Image Height:  720
# Image Width:  1280
# image_0693.png
# Image Path:  test_images/image_0693.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0693.png
# Image Height:  720
# Image Width:  1280
# image_0616.png
# Image Path:  test_images/image_0616.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0616.png
# Image Height:  720
# Image Width:  1280
# image_0125.png
# Image Path:  test_images/image_0125.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0125.png
# Image Height:  720
# Image Width:  1280
# image_1370.png
# Image Path:  test_images/image_1370.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1370.png
# Image Height:  720
# Image Width:  1280
# image_1249.png
# Image Path:  test_images/image_1249.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1249.png
# Image Height:  720
# Image Width:  1280
# image_1137.png
# Image Path:  test_images/image_1137.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1137.png
# Image Height:  720
# Image Width:  1280
# image_0619.png
# Image Path:  test_images/image_0619.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0619.png
# Image Height:  720
# Image Width:  1280
# image_0490.png
# Image Path:  test_images/image_0490.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0490.png
# Image Height:  720
# Image Width:  1280
# image_0106.png
# Image Path:  test_images/image_0106.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0106.png
# Image Height:  720
# Image Width:  1280
# image_1359.png
# Image Path:  test_images/image_1359.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1359.png
# Image Height:  720
# Image Width:  1280
# image_0330.png
# Image Path:  test_images/image_0330.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0330.png
# Image Height:  720
# Image Width:  1280
# image_1459.png
# Image Path:  test_images/image_1459.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1459.png
# Image Height:  720
# Image Width:  1280
# image_1049.png
# Image Path:  test_images/image_1049.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1049.png
# Image Height:  720
# Image Width:  1280
# image_0093.png
# Image Path:  test_images/image_0093.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0093.png
# Image Height:  720
# Image Width:  1280
# image_1058.png
# Image Path:  test_images/image_1058.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1058.png
# Image Height:  720
# Image Width:  1280
# image_1581.png
# Image Path:  test_images/image_1581.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1581.png
# Image Height:  720
# Image Width:  1280
# image_0478.png
# Image Path:  test_images/image_0478.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0478.png
# Image Height:  720
# Image Width:  1280
# image_0705.png
# Image Path:  test_images/image_0705.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0705.png
# Image Height:  720
# Image Width:  1280
# image_0927.png
# Image Path:  test_images/image_0927.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0927.png
# Image Height:  720
# Image Width:  1280
# image_0904.png
# Image Path:  test_images/image_0904.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0904.png
# Image Height:  720
# Image Width:  1280
# image_1128.png
# Image Path:  test_images/image_1128.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1128.png
# Image Height:  720
# Image Width:  1280
# image_0653.png
# Image Path:  test_images/image_0653.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0653.png
# Image Height:  720
# Image Width:  1280
# image_0157.png
# Image Path:  test_images/image_0157.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0157.png
# Image Height:  720
# Image Width:  1280
# image_1250.png
# Image Path:  test_images/image_1250.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1250.png
# Image Height:  720
# Image Width:  1280
# image_1539.png
# Image Path:  test_images/image_1539.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1539.png
# Image Height:  720
# Image Width:  1280
# image_1383.png
# Image Path:  test_images/image_1383.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1383.png
# Image Height:  720
# Image Width:  1280
# image_1313.png
# Image Path:  test_images/image_1313.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1313.png
# Image Height:  720
# Image Width:  1280
# image_0057.png
# Image Path:  test_images/image_0057.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0057.png
# Image Height:  720
# Image Width:  1280
# image_1559.png
# Image Path:  test_images/image_1559.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1559.png
# Image Height:  720
# Image Width:  1280
# image_0906.png
# Image Path:  test_images/image_0906.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0906.png
# Image Height:  720
# Image Width:  1280
# image_0832.png
# Image Path:  test_images/image_0832.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0832.png
# Image Height:  720
# Image Width:  1280
# image_0153.png
# Image Path:  test_images/image_0153.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0153.png
# Image Height:  720
# Image Width:  1280
# image_1366.png
# Image Path:  test_images/image_1366.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1366.png
# Image Height:  720
# Image Width:  1280
# image_0089.png
# Image Path:  test_images/image_0089.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0089.png
# Image Height:  720
# Image Width:  1280
# image_0924.png
# Image Path:  test_images/image_0924.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0924.png
# Image Height:  720
# Image Width:  1280
# image_1509.png
# Image Path:  test_images/image_1509.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1509.png
# Image Height:  720
# Image Width:  1280
# image_0322.png
# Image Path:  test_images/image_0322.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0322.png
# Image Height:  720
# Image Width:  1280
# image_1129.png
# Image Path:  test_images/image_1129.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1129.png
# Image Height:  720
# Image Width:  1280
# image_0380.png
# Image Path:  test_images/image_0380.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0380.png
# Image Height:  720
# Image Width:  1280
# image_0762.png
# Image Path:  test_images/image_0762.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0762.png
# Image Height:  720
# Image Width:  1280
# image_1134.png
# Image Path:  test_images/image_1134.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1134.png
# Image Height:  720
# Image Width:  1280
# image_0680.png
# Image Path:  test_images/image_0680.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0680.png
# Image Height:  720
# Image Width:  1280
# image_1438.png
# Image Path:  test_images/image_1438.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1438.png
# Image Height:  720
# Image Width:  1280
# image_0596.png
# Image Path:  test_images/image_0596.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0596.png
# Image Height:  720
# Image Width:  1280
# image_1132.png
# Image Path:  test_images/image_1132.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1132.png
# Image Height:  720
# Image Width:  1280
# image_0452.png
# Image Path:  test_images/image_0452.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0452.png
# Image Height:  720
# Image Width:  1280
# image_1544.png
# Image Path:  test_images/image_1544.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1544.png
# Image Height:  720
# Image Width:  1280
# image_0556.png
# Image Path:  test_images/image_0556.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0556.png
# Image Height:  720
# Image Width:  1280
# image_0373.png
# Image Path:  test_images/image_0373.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0373.png
# Image Height:  720
# Image Width:  1280
# image_0645.png
# Image Path:  test_images/image_0645.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0645.png
# Image Height:  720
# Image Width:  1280
# image_1598.png
# Image Path:  test_images/image_1598.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1598.png
# Image Height:  720
# Image Width:  1280
# image_1202.png
# Image Path:  test_images/image_1202.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1202.png
# Image Height:  720
# Image Width:  1280
# image_0649.png
# Image Path:  test_images/image_0649.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0649.png
# Image Height:  720
# Image Width:  1280
# image_1523.png
# Image Path:  test_images/image_1523.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1523.png
# Image Height:  720
# Image Width:  1280
# image_1206.png
# Image Path:  test_images/image_1206.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1206.png
# Image Height:  720
# Image Width:  1280
# image_1117.png
# Image Path:  test_images/image_1117.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1117.png
# Image Height:  720
# Image Width:  1280
# image_0194.png
# Image Path:  test_images/image_0194.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0194.png
# Image Height:  720
# Image Width:  1280
# image_1082.png
# Image Path:  test_images/image_1082.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1082.png
# Image Height:  720
# Image Width:  1280
# image_1579.png
# Image Path:  test_images/image_1579.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1579.png
# Image Height:  720
# Image Width:  1280
# image_0543.png
# Image Path:  test_images/image_0543.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0543.png
# Image Height:  720
# Image Width:  1280
# image_0285.png
# Image Path:  test_images/image_0285.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0285.png
# Image Height:  720
# Image Width:  1280
# image_0668.png
# Image Path:  test_images/image_0668.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0668.png
# Image Height:  720
# Image Width:  1280
# image_0234.png
# Image Path:  test_images/image_0234.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0234.png
# Image Height:  720
# Image Width:  1280
# image_0181.png
# Image Path:  test_images/image_0181.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0181.png
# Image Height:  720
# Image Width:  1280
# image_1079.png
# Image Path:  test_images/image_1079.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1079.png
# Image Height:  720
# Image Width:  1280
# image_0436.png
# Image Path:  test_images/image_0436.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0436.png
# Image Height:  720
# Image Width:  1280
# image_0640.png
# Image Path:  test_images/image_0640.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0640.png
# Image Height:  720
# Image Width:  1280
# image_1296.png
# Image Path:  test_images/image_1296.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1296.png
# Image Height:  720
# Image Width:  1280
# image_0259.png
# Image Path:  test_images/image_0259.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0259.png
# Image Height:  720
# Image Width:  1280
# image_0312.png
# Image Path:  test_images/image_0312.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0312.png
# Image Height:  720
# Image Width:  1280
# image_0008.png
# Image Path:  test_images/image_0008.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0008.png
# Image Height:  720
# Image Width:  1280
# image_1105.png
# Image Path:  test_images/image_1105.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1105.png
# Image Height:  720
# Image Width:  1280
# image_1347.png
# Image Path:  test_images/image_1347.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1347.png
# Image Height:  720
# Image Width:  1280
# image_0613.png
# Image Path:  test_images/image_0613.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0613.png
# Image Height:  720
# Image Width:  1280
# image_1590.png
# Image Path:  test_images/image_1590.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1590.png
# Image Height:  720
# Image Width:  1280
# image_0933.png
# Image Path:  test_images/image_0933.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0933.png
# Image Height:  720
# Image Width:  1280
# image_0866.png
# Image Path:  test_images/image_0866.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0866.png
# Image Height:  720
# Image Width:  1280
# image_0137.png
# Image Path:  test_images/image_0137.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0137.png
# Image Height:  720
# Image Width:  1280
# image_0191.png
# Image Path:  test_images/image_0191.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0191.png
# Image Height:  720
# Image Width:  1280
# image_0003.png
# Image Path:  test_images/image_0003.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0003.png
# Image Height:  720
# Image Width:  1280
# image_0985.png
# Image Path:  test_images/image_0985.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0985.png
# Image Height:  720
# Image Width:  1280
# image_0506.png
# Image Path:  test_images/image_0506.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0506.png
# Image Height:  720
# Image Width:  1280
# image_1130.png
# Image Path:  test_images/image_1130.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1130.png
# Image Height:  720
# Image Width:  1280
# image_0065.png
# Image Path:  test_images/image_0065.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0065.png
# Image Height:  720
# Image Width:  1280
# image_1541.png
# Image Path:  test_images/image_1541.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1541.png
# Image Height:  720
# Image Width:  1280
# image_0149.png
# Image Path:  test_images/image_0149.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0149.png
# Image Height:  720
# Image Width:  1280
# image_1188.png
# Image Path:  test_images/image_1188.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1188.png
# Image Height:  720
# Image Width:  1280
# image_0623.png
# Image Path:  test_images/image_0623.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0623.png
# Image Height:  720
# Image Width:  1280
# image_0863.png
# Image Path:  test_images/image_0863.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0863.png
# Image Height:  720
# Image Width:  1280
# image_0723.png
# Image Path:  test_images/image_0723.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0723.png
# Image Height:  720
# Image Width:  1280
# image_1005.png
# Image Path:  test_images/image_1005.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1005.png
# Image Height:  720
# Image Width:  1280
# image_0962.png
# Image Path:  test_images/image_0962.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0962.png
# Image Height:  720
# Image Width:  1280
# image_0496.png
# Image Path:  test_images/image_0496.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0496.png
# Image Height:  720
# Image Width:  1280
# image_0759.png
# Image Path:  test_images/image_0759.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0759.png
# Image Height:  720
# Image Width:  1280
# image_0192.png
# Image Path:  test_images/image_0192.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0192.png
# Image Height:  720
# Image Width:  1280
# image_0918.png
# Image Path:  test_images/image_0918.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0918.png
# Image Height:  720
# Image Width:  1280
# image_0586.png
# Image Path:  test_images/image_0586.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0586.png
# Image Height:  720
# Image Width:  1280
# image_1521.png
# Image Path:  test_images/image_1521.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1521.png
# Image Height:  720
# Image Width:  1280
# image_1412.png
# Image Path:  test_images/image_1412.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1412.png
# Image Height:  720
# Image Width:  1280
# image_0377.png
# Image Path:  test_images/image_0377.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0377.png
# Image Height:  720
# Image Width:  1280
# image_0243.png
# Image Path:  test_images/image_0243.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0243.png
# Image Height:  720
# Image Width:  1280
# image_1266.png
# Image Path:  test_images/image_1266.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1266.png
# Image Height:  720
# Image Width:  1280
# image_0504.png
# Image Path:  test_images/image_0504.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0504.png
# Image Height:  720
# Image Width:  1280
# image_1091.png
# Image Path:  test_images/image_1091.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1091.png
# Image Height:  720
# Image Width:  1280
# image_0545.png
# Image Path:  test_images/image_0545.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0545.png
# Image Height:  720
# Image Width:  1280
# image_1146.png
# Image Path:  test_images/image_1146.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1146.png
# Image Height:  720
# Image Width:  1280
# image_1580.png
# Image Path:  test_images/image_1580.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1580.png
# Image Height:  720
# Image Width:  1280
# image_1394.png
# Image Path:  test_images/image_1394.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1394.png
# Image Height:  720
# Image Width:  1280
# image_0804.png
# Image Path:  test_images/image_0804.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0804.png
# Image Height:  720
# Image Width:  1280
# image_0439.png
# Image Path:  test_images/image_0439.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0439.png
# Image Height:  720
# Image Width:  1280
# image_0517.png
# Image Path:  test_images/image_0517.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0517.png
# Image Height:  720
# Image Width:  1280
# image_1572.png
# Image Path:  test_images/image_1572.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1572.png
# Image Height:  720
# Image Width:  1280
# image_0677.png
# Image Path:  test_images/image_0677.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0677.png
# Image Height:  720
# Image Width:  1280
# image_1499.png
# Image Path:  test_images/image_1499.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1499.png
# Image Height:  720
# Image Width:  1280
# image_0028.png
# Image Path:  test_images/image_0028.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0028.png
# Image Height:  720
# Image Width:  1280
# image_0252.png
# Image Path:  test_images/image_0252.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0252.png
# Image Height:  720
# Image Width:  1280
# image_1111.png
# Image Path:  test_images/image_1111.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1111.png
# Image Height:  720
# Image Width:  1280
# image_1421.png
# Image Path:  test_images/image_1421.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1421.png
# Image Height:  720
# Image Width:  1280
# image_1035.png
# Image Path:  test_images/image_1035.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1035.png
# Image Height:  720
# Image Width:  1280
# image_0769.png
# Image Path:  test_images/image_0769.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0769.png
# Image Height:  720
# Image Width:  1280
# image_1411.png
# Image Path:  test_images/image_1411.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1411.png
# Image Height:  720
# Image Width:  1280
# image_0407.png
# Image Path:  test_images/image_0407.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0407.png
# Image Height:  720
# Image Width:  1280
# image_0238.png
# Image Path:  test_images/image_0238.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0238.png
# Image Height:  720
# Image Width:  1280
# image_0791.png
# Image Path:  test_images/image_0791.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0791.png
# Image Height:  720
# Image Width:  1280
# image_1265.png
# Image Path:  test_images/image_1265.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1265.png
# Image Height:  720
# Image Width:  1280
# image_0856.png
# Image Path:  test_images/image_0856.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0856.png
# Image Height:  720
# Image Width:  1280
# image_0463.png
# Image Path:  test_images/image_0463.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0463.png
# Image Height:  720
# Image Width:  1280
# image_0629.png
# Image Path:  test_images/image_0629.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0629.png
# Image Height:  720
# Image Width:  1280
# image_1587.png
# Image Path:  test_images/image_1587.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1587.png
# Image Height:  720
# Image Width:  1280
# image_0821.png
# Image Path:  test_images/image_0821.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0821.png
# Image Height:  720
# Image Width:  1280
# image_1330.png
# Image Path:  test_images/image_1330.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1330.png
# Image Height:  720
# Image Width:  1280
# image_0315.png
# Image Path:  test_images/image_0315.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0315.png
# Image Height:  720
# Image Width:  1280
# image_0535.png
# Image Path:  test_images/image_0535.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0535.png
# Image Height:  720
# Image Width:  1280
# image_0570.png
# Image Path:  test_images/image_0570.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0570.png
# Image Height:  720
# Image Width:  1280
# image_0919.png
# Image Path:  test_images/image_0919.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0919.png
# Image Height:  720
# Image Width:  1280
# image_0607.png
# Image Path:  test_images/image_0607.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0607.png
# Image Height:  720
# Image Width:  1280
# image_1006.png
# Image Path:  test_images/image_1006.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1006.png
# Image Height:  720
# Image Width:  1280
# image_1189.png
# Image Path:  test_images/image_1189.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1189.png
# Image Height:  720
# Image Width:  1280
# image_1124.png
# Image Path:  test_images/image_1124.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1124.png
# Image Height:  720
# Image Width:  1280
# image_0502.png
# Image Path:  test_images/image_0502.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0502.png
# Image Height:  720
# Image Width:  1280
# image_0384.png
# Image Path:  test_images/image_0384.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0384.png
# Image Height:  720
# Image Width:  1280
# image_1356.png
# Image Path:  test_images/image_1356.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1356.png
# Image Height:  720
# Image Width:  1280
# image_0309.png
# Image Path:  test_images/image_0309.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0309.png
# Image Height:  720
# Image Width:  1280
# image_1251.png
# Image Path:  test_images/image_1251.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1251.png
# Image Height:  720
# Image Width:  1280
# image_0828.png
# Image Path:  test_images/image_0828.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0828.png
# Image Height:  720
# Image Width:  1280
# image_1217.png
# Image Path:  test_images/image_1217.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1217.png
# Image Height:  720
# Image Width:  1280
# image_1122.png
# Image Path:  test_images/image_1122.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1122.png
# Image Height:  720
# Image Width:  1280
# image_1589.png
# Image Path:  test_images/image_1589.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1589.png
# Image Height:  720
# Image Width:  1280
# image_0663.png
# Image Path:  test_images/image_0663.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0663.png
# Image Height:  720
# Image Width:  1280
# image_0967.png
# Image Path:  test_images/image_0967.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0967.png
# Image Height:  720
# Image Width:  1280
# image_0059.png
# Image Path:  test_images/image_0059.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0059.png
# Image Height:  720
# Image Width:  1280
# image_1024.png
# Image Path:  test_images/image_1024.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1024.png
# Image Height:  720
# Image Width:  1280
# image_0937.png
# Image Path:  test_images/image_0937.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0937.png
# Image Height:  720
# Image Width:  1280
# image_1515.png
# Image Path:  test_images/image_1515.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1515.png
# Image Height:  720
# Image Width:  1280
# image_1290.png
# Image Path:  test_images/image_1290.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1290.png
# Image Height:  720
# Image Width:  1280
# image_0978.png
# Image Path:  test_images/image_0978.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0978.png
# Image Height:  720
# Image Width:  1280
# image_1332.png
# Image Path:  test_images/image_1332.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1332.png
# Image Height:  720
# Image Width:  1280
# image_1281.png
# Image Path:  test_images/image_1281.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1281.png
# Image Height:  720
# Image Width:  1280
# image_0816.png
# Image Path:  test_images/image_0816.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0816.png
# Image Height:  720
# Image Width:  1280
# image_0460.png
# Image Path:  test_images/image_0460.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0460.png
# Image Height:  720
# Image Width:  1280
# image_0554.png
# Image Path:  test_images/image_0554.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0554.png
# Image Height:  720
# Image Width:  1280
# image_1467.png
# Image Path:  test_images/image_1467.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1467.png
# Image Height:  720
# Image Width:  1280
# image_1101.png
# Image Path:  test_images/image_1101.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1101.png
# Image Height:  720
# Image Width:  1280
# image_0995.png
# Image Path:  test_images/image_0995.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0995.png
# Image Height:  720
# Image Width:  1280
# image_0468.png
# Image Path:  test_images/image_0468.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0468.png
# Image Height:  720
# Image Width:  1280
# image_0833.png
# Image Path:  test_images/image_0833.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0833.png
# Image Height:  720
# Image Width:  1280
# image_1133.png
# Image Path:  test_images/image_1133.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1133.png
# Image Height:  720
# Image Width:  1280
# image_1288.png
# Image Path:  test_images/image_1288.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1288.png
# Image Height:  720
# Image Width:  1280
# image_0067.png
# Image Path:  test_images/image_0067.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0067.png
# Image Height:  720
# Image Width:  1280
# image_0755.png
# Image Path:  test_images/image_0755.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0755.png
# Image Height:  720
# Image Width:  1280
# image_1368.png
# Image Path:  test_images/image_1368.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1368.png
# Image Height:  720
# Image Width:  1280
# image_0363.png
# Image Path:  test_images/image_0363.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0363.png
# Image Height:  720
# Image Width:  1280
# image_0560.png
# Image Path:  test_images/image_0560.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0560.png
# Image Height:  720
# Image Width:  1280
# image_0867.png
# Image Path:  test_images/image_0867.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0867.png
# Image Height:  720
# Image Width:  1280
# image_0217.png
# Image Path:  test_images/image_0217.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0217.png
# Image Height:  720
# Image Width:  1280
# image_0946.png
# Image Path:  test_images/image_0946.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0946.png
# Image Height:  720
# Image Width:  1280
# image_0235.png
# Image Path:  test_images/image_0235.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0235.png
# Image Height:  720
# Image Width:  1280
# image_1041.png
# Image Path:  test_images/image_1041.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1041.png
# Image Height:  720
# Image Width:  1280
# image_1026.png
# Image Path:  test_images/image_1026.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1026.png
# Image Height:  720
# Image Width:  1280
# image_0684.png
# Image Path:  test_images/image_0684.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0684.png
# Image Height:  720
# Image Width:  1280
# image_0109.png
# Image Path:  test_images/image_0109.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0109.png
# Image Height:  720
# Image Width:  1280
# image_0299.png
# Image Path:  test_images/image_0299.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0299.png
# Image Height:  720
# Image Width:  1280
# image_0998.png
# Image Path:  test_images/image_0998.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0998.png
# Image Height:  720
# Image Width:  1280
# image_0325.png
# Image Path:  test_images/image_0325.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0325.png
# Image Height:  720
# Image Width:  1280
# image_0685.png
# Image Path:  test_images/image_0685.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0685.png
# Image Height:  720
# Image Width:  1280
# image_0348.png
# Image Path:  test_images/image_0348.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0348.png
# Image Height:  720
# Image Width:  1280
# image_0859.png
# Image Path:  test_images/image_0859.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0859.png
# Image Height:  720
# Image Width:  1280
# image_1390.png
# Image Path:  test_images/image_1390.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1390.png
# Image Height:  720
# Image Width:  1280
# image_0537.png
# Image Path:  test_images/image_0537.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0537.png
# Image Height:  720
# ...
# Image Height:  720
# Image Width:  1280
# image_0965.png
# Image Path:  test_images/image_0965.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0965.png
# Image Height:  720
# Image Width:  1280
# image_1285.png
# Image Path:  test_images/image_1285.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1285.png
# Image Height:  720
# Image Width:  1280
# image_1144.png
# Image Path:  test_images/image_1144.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1144.png
# Image Height:  720
# Image Width:  1280
# image_0566.png
# Image Path:  test_images/image_0566.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0566.png
# Image Height:  720
# Image Width:  1280
# image_0202.png
# Image Path:  test_images/image_0202.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0202.png
# Image Height:  720
# Image Width:  1280
# image_1454.png
# Image Path:  test_images/image_1454.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1454.png
# Image Height:  720
# Image Width:  1280
# image_1259.png
# Image Path:  test_images/image_1259.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1259.png
# Image Height:  720
# Image Width:  1280
# image_1060.png
# Image Path:  test_images/image_1060.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1060.png
# Image Height:  720
# Image Width:  1280
# image_0936.png
# Image Path:  test_images/image_0936.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0936.png
# Image Height:  720
# Image Width:  1280
# image_1320.png
# Image Path:  test_images/image_1320.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1320.png
# Image Height:  720
# Image Width:  1280
# image_0546.png
# Image Path:  test_images/image_0546.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0546.png
# Image Height:  720
# Image Width:  1280
# image_0521.png
# Image Path:  test_images/image_0521.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0521.png
# Image Height:  720
# Image Width:  1280
# image_1213.png
# Image Path:  test_images/image_1213.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1213.png
# Image Height:  720
# Image Width:  1280
# image_0657.png
# Image Path:  test_images/image_0657.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0657.png
# Image Height:  720
# Image Width:  1280
# image_0424.png
# Image Path:  test_images/image_0424.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0424.png
# Image Height:  720
# Image Width:  1280
# image_0956.png
# Image Path:  test_images/image_0956.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0956.png
# Image Height:  720
# Image Width:  1280
# image_0604.png
# Image Path:  test_images/image_0604.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0604.png
# Image Height:  720
# Image Width:  1280
# image_0794.png
# Image Path:  test_images/image_0794.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0794.png
# Image Height:  720
# Image Width:  1280
# image_1556.png
# Image Path:  test_images/image_1556.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1556.png
# Image Height:  720
# Image Width:  1280
# image_0622.png
# Image Path:  test_images/image_0622.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0622.png
# Image Height:  720
# Image Width:  1280
# image_1351.png
# Image Path:  test_images/image_1351.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1351.png
# Image Height:  720
# Image Width:  1280
# image_1155.png
# Image Path:  test_images/image_1155.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1155.png
# Image Height:  720
# Image Width:  1280
# image_1018.png
# Image Path:  test_images/image_1018.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1018.png
# Image Height:  720
# Image Width:  1280
# image_0090.png
# Image Path:  test_images/image_0090.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0090.png
# Image Height:  720
# Image Width:  1280
# image_0085.png
# Image Path:  test_images/image_0085.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0085.png
# Image Height:  720
# Image Width:  1280
# image_0899.png
# Image Path:  test_images/image_0899.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0899.png
# Image Height:  720
# Image Width:  1280
# image_1364.png
# Image Path:  test_images/image_1364.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1364.png
# Image Height:  720
# Image Width:  1280
# image_1037.png
# Image Path:  test_images/image_1037.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1037.png
# Image Height:  720
# Image Width:  1280
# image_0324.png
# Image Path:  test_images/image_0324.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0324.png
# Image Height:  720
# Image Width:  1280
# image_0387.png
# Image Path:  test_images/image_0387.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0387.png
# Image Height:  720
# Image Width:  1280
# image_1585.png
# Image Path:  test_images/image_1585.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1585.png
# Image Height:  720
# Image Width:  1280
# image_1385.png
# Image Path:  test_images/image_1385.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1385.png
# Image Height:  720
# Image Width:  1280
# image_0955.png
# Image Path:  test_images/image_0955.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0955.png
# Image Height:  720
# Image Width:  1280
# image_0651.png
# Image Path:  test_images/image_0651.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0651.png
# Image Height:  720
# Image Width:  1280
# image_1039.png
# Image Path:  test_images/image_1039.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1039.png
# Image Height:  720
# Image Width:  1280
# image_0611.png
# Image Path:  test_images/image_0611.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0611.png
# Image Height:  720
# Image Width:  1280
# image_1179.png
# Image Path:  test_images/image_1179.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1179.png
# Image Height:  720
# Image Width:  1280
# image_1441.png
# Image Path:  test_images/image_1441.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1441.png
# Image Height:  720
# Image Width:  1280
# image_1372.png
# Image Path:  test_images/image_1372.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1372.png
# Image Height:  720
# Image Width:  1280
# image_0910.png
# Image Path:  test_images/image_0910.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0910.png
# Image Height:  720
# Image Width:  1280
# image_1027.png
# Image Path:  test_images/image_1027.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1027.png
# Image Height:  720
# Image Width:  1280
# image_0058.png
# Image Path:  test_images/image_0058.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0058.png
# Image Height:  720
# Image Width:  1280
# image_0624.png
# Image Path:  test_images/image_0624.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0624.png
# Image Height:  720
# Image Width:  1280
# image_0626.png
# Image Path:  test_images/image_0626.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0626.png
# Image Height:  720
# Image Width:  1280
# image_0304.png
# Image Path:  test_images/image_0304.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0304.png
# Image Height:  720
# Image Width:  1280
# image_1299.png
# Image Path:  test_images/image_1299.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1299.png
# Image Height:  720
# Image Width:  1280
# image_0291.png
# Image Path:  test_images/image_0291.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0291.png
# Image Height:  720
# Image Width:  1280
# image_1271.png
# Image Path:  test_images/image_1271.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1271.png
# Image Height:  720
# Image Width:  1280
# image_0305.png
# Image Path:  test_images/image_0305.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0305.png
# Image Height:  720
# Image Width:  1280
# image_0368.png
# Image Path:  test_images/image_0368.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0368.png
# Image Height:  720
# Image Width:  1280
# image_1095.png
# Image Path:  test_images/image_1095.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1095.png
# Image Height:  720
# Image Width:  1280
# image_0530.png
# Image Path:  test_images/image_0530.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0530.png
# Image Height:  720
# Image Width:  1280
# image_0014.png
# Image Path:  test_images/image_0014.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0014.png
# Image Height:  720
# Image Width:  1280
# image_1100.png
# Image Path:  test_images/image_1100.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1100.png
# Image Height:  720
# Image Width:  1280
# image_1379.png
# Image Path:  test_images/image_1379.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1379.png
# Image Height:  720
# Image Width:  1280
# image_1197.png
# Image Path:  test_images/image_1197.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1197.png
# Image Height:  720
# Image Width:  1280
# image_0483.png
# Image Path:  test_images/image_0483.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0483.png
# Image Height:  720
# Image Width:  1280
# image_0894.png
# Image Path:  test_images/image_0894.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0894.png
# Image Height:  720
# Image Width:  1280
# image_0855.png
# Image Path:  test_images/image_0855.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0855.png
# Image Height:  720
# Image Width:  1280
# image_1138.png
# Image Path:  test_images/image_1138.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1138.png
# Image Height:  720
# Image Width:  1280
# image_0774.png
# Image Path:  test_images/image_0774.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0774.png
# Image Height:  720
# Image Width:  1280
# image_0549.png
# Image Path:  test_images/image_0549.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0549.png
# Image Height:  720
# Image Width:  1280
# image_0416.png
# Image Path:  test_images/image_0416.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0416.png
# Image Height:  720
# Image Width:  1280
# image_1478.png
# Image Path:  test_images/image_1478.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1478.png
# Image Height:  720
# Image Width:  1280
# image_1072.png
# Image Path:  test_images/image_1072.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_1072.png
# Image Height:  720
# Image Width:  1280
# image_0083.png
# Image Path:  test_images/image_0083.png
# Suspect Path:  suspects/content/drive/Shareddrives/ZINDI Data Science/ADPL/Competition Data/CV/Data Prep/Test (0-1599)/merged/crops/image_0083.png
# Image Height:  720
# Image Width:  1280

# %%
image_path = '/content/test_images/image_0000.png'
img = cv2.imread(image_path)
img_h, img_w = img.shape[:2]
print(img_h, img_w)

# %%
if os.path.exists("/content/test_images/.DS_Store"):
  os.remove('/content/test_images/.DS_Store')
  print("Deleted")
else:
  print("The file does not exist")
# Out:
# The file does not exist

# %%
if os.path.exists("/content/suspects/.DS_Store"):
  os.remove('/content/suspects/.DS_Store')
  print("Deleted")
else:
  print("The file does not exist")
# Out:
# The file does not exist

# %%
df.head(10)

# %%
import os
path = "suspects/image_1537.png"
if os.path.exists(path):
     print("Path exist")
else:
  print("Path does not exist:", path)
